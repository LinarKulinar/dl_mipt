# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>"Глубокое обучение". Продвинутый поток</b></h3>
#
# <h2 style="text-align: center;"><b>День 3. Библиотека <a href="http://pandas.pydata.org/">pandas</a></b></h2>

# %% [markdown]
# Библиотека `pandas` активно используется в современном data science для работы с данными, которые могут быть представлены в виде таблиц (а это очень, очень большая часть данных)

# %% [markdown]
# `pandas` есть в пакете Anaconda, но если вдруг у Вас её по каким-то причинам нет, то можно установить, раскомментировав следующую команду:

# %%
# !pip install numpy pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## pd.Series

# %% [markdown]
# Одномерный набор данных. Похож на `np.ndarray`, но с более расширенным функционалом

# %%
np.random.seed(42)

# %%
np_array = np.random.randint(low=-15, high=20, size=4)
np_array
# Out:
# array([ 3,  7, -5, -5])

# %%
# Series можно сделать из массива
pd_series_1 = pd.Series(np_array)
pd_series_1
# Out:
# 0    3
# 1    7
# 2   -5
# 3   -5
# dtype: int64

# %%
# Так же можно аннотировать индексы, чтобы потом было более удобно обращаться к элементам
pd_series_2 = pd.Series(np_array, index=['1st day', '2nd day', '3rd day', '4th day'])
pd_series_2
# Out:
# 1st day    3
# 2nd day    7
# 3rd day   -5
# 4th day   -5
# dtype: int64

# %%
pd_series_2['4th day']
# Out:
# -5

# %%
# А еще можно дать pd.Series имя, чтобы было совсем красиво
pd_series_3 = pd.Series(np_array, index=['1st day', '2nd day', '3rd day', '4th day'], name='Temperature')
pd_series_3
# Out:
# 1st day    3
# 2nd day    7
# 3rd day   -5
# 4th day   -5
# Name: Temperature, dtype: int64

# %%
# с индексами можно работать так же, как и в случае с обычным list
print(pd_series_3[0])
print('*'*5)
print(pd_series_3[1:3])
print('*'*5)
print(pd_series_3[::-1])
# Out:
# 3
# *****
# 2nd day    7
# 3rd day   -5
# Name: Temperature, dtype: int64
# *****
# 4th day   -5
# 3rd day   -5
# 2nd day    7
# 1st day    3
# Name: Temperature, dtype: int64

# %% [markdown]
# `series` можно отсортировать как по значениям, так и по индексу

# %%
pd_series_3.sort_index()
# Out:
# 1st day    3
# 2nd day    7
# 3rd day   -5
# 4th day   -5
# Name: Temperature, dtype: int64

# %%
pd_series_3.sort_values()
# Out:
# 3rd day   -5
# 4th day   -5
# 1st day    3
# 2nd day    7
# Name: Temperature, dtype: int64

# %% [markdown]
# с `series` можно работать как с `np.ndarray`

# %%
pd_series_3 + 100
# Out:
# 1st day    103
# 2nd day    107
# 3rd day     95
# 4th day     95
# Name: Temperature, dtype: int64

# %%
np.exp(pd_series_3)
# Out:
# 1st day      20.085537
# 2nd day    1096.633158
# 3rd day       0.006738
# 4th day       0.006738
# Name: Temperature, dtype: float64

# %%
term_1 = pd.Series(np.random.randint(0, 10, 5))
term_2 = pd.Series(np.random.randint(0, 10, 6))

print('Term1:\n{}\n\nTerm2:\n{}\n\nSum:\n{}'.format(term_1, term_2, term_1 + term_2))
# Out:
# Term1:
# 0    7
# 1    4
# 2    3
# 3    7
# 4    7
# dtype: int64
#
# Term2:
# 0    2
# 1    5
# 2    4
# 3    1
# 4    7
# 5    5
# dtype: int64
#
# Sum:
# 0     9.0
# 1     9.0
# 2     7.0
# 3     8.0
# 4    14.0
# 5     NaN
# dtype: float64

# %%
term_1.shape
# Out:
# (5,)

# %%
date_range = pd.date_range('20190101', periods=10)
pd_series_4 = pd.Series(np.random.rand(10), date_range)
pd_series_4
# Out:
# 2019-01-01    0.391061
# 2019-01-02    0.182236
# 2019-01-03    0.755361
# 2019-01-04    0.425156
# 2019-01-05    0.207942
# 2019-01-06    0.567700
# 2019-01-07    0.031313
# 2019-01-08    0.842285
# 2019-01-09    0.449754
# 2019-01-10    0.395150
# Freq: D, dtype: float64

# %%
pd_series_4 > 0.5
# Out:
# 2019-01-01    False
# 2019-01-02    False
# 2019-01-03     True
# 2019-01-04    False
# 2019-01-05    False
# 2019-01-06     True
# 2019-01-07    False
# 2019-01-08     True
# 2019-01-09    False
# 2019-01-10     True
# Freq: D, dtype: bool

# %% [markdown]
# в качестве индекса можно указать выражение, и нам будут возвращены только те элементы, для которых знвчение является `True`

# %%
pd_series_4[pd_series_4 > 0.5]
# Out:
# 2019-01-03    0.973756
# 2019-01-06    0.618386
# 2019-01-08    0.983231
# 2019-01-10    0.859940
# dtype: float64

# %%
pd_series_4[(pd_series_4 > 0.5) & (pd_series_4 < 0.6)]
# Out:
# Series([], Freq: D, dtype: float64)

# %%
pd_series_4[(pd_series_4 > 0.6) | (pd_series_4 < 0.2)]
# Out:
# 2019-01-02    0.046666
# 2019-01-03    0.973756
# 2019-01-05    0.090606
# 2019-01-06    0.618386
# 2019-01-08    0.983231
# 2019-01-10    0.859940
# dtype: float64

# %% [markdown]
# ## DataFrame
#
# Двумерная таблица данных. Имеет индекс и набор столбцов (возможно, имеющих разные типы). Таблицу можно построить, например, из словаря, значениями в котором являются одномерные наборы данных.

# %%
# Dataframe можно составить из словаря. Ключ будет соответсовать колонке
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['one']['c']
# Out:
# 3.0

# %%
df.one
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %% [markdown]
# Если указать диапазон индексов, то это означает диапазон строк. Причём **последняя строка включается в таблицу.**
#
# Диапазон целых чисел даёт диапазон строк с такими номерами, **не включая последнюю строку** (как обычно при индексировании списков).
#
# На это стоит обратить внимание

# %%
df['b':'d']
# Out:
#    one  two
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
df[3:1:-1]
# Out:
#    one  two
# d  NaN    4
# c  3.0    3

# %%
df['three'] = df['one'] * df['two']
df
# Out:
#    one  two  three
# a  1.0    1    1.0
# b  2.0    2    4.0
# c  3.0    3    9.0
# d  NaN    4    NaN

# %%
# concatinating
df2=pd.DataFrame({'one':{'e':0,'f':1},'one_tr':{'e':2}})
df2
# Out:
#    one  one_tr
# e    0     2.0
# f    1     NaN

# %%
pd.concat([df,df2], sort=False)
# Out:
#    one  two  three  one_tr
# a  1.0  1.0    1.0     NaN
# b  2.0  2.0    4.0     NaN
# c  3.0  3.0    9.0     NaN
# d  NaN  4.0    NaN     NaN
# e  0.0  NaN    NaN     2.0
# f  1.0  NaN    NaN     NaN

# %% [markdown]
# Теперь попробуем поработать с настоящими данными

# %% [markdown]
# ### Скачать данные: https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps

# %%
# !wget https://www.dropbox.com/s/o9uiqxb3yr6ch6k/app-store-apple-data-set-10k-apps.zip?dl=0
# !unzip app-store-apple-data-set-10k-apps.zip?dl=0

# %%
data = pd.read_csv('AppleStore.csv')

# вывести первые 5 строк
# data.head(10)
# вывести последние 5 строк
# data.tail(5)
# вывести 5 случайных строк
data.sample(5)
# Out:
#       Unnamed: 0          id  \
# 5676        7713  1092704571
# 1677        1951   582719476
# 2892        3457   908842747
# 1880        2183   625985591
# 3785        4644   993570169
#
#                                              track_name  size_bytes currency  \
# 5676                            UA Shop by Under Armour   202311680      USD
# 1677  Instant Fitness : 600+ exercises, 100+ workout...    80175104      USD
# 2892                                         Themeboard    52408320      USD
# 1880                                       Stupid Test!    31798272      USD
# 3785                                       Swaggy Ninja    31567872      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 5676   0.00               741                16          4.5              4.5
# 1677   9.99               571               214          4.5              4.5
# 2892   0.00               704                87          3.0              2.5
# 1880   0.00              2485              2112          4.5              5.0
# 3785   0.00              1210               119          4.5              4.0
#
#         ver cont_rating       prime_genre  sup_devices.num  ipadSc_urls.num  \
# 5676   1.15          4+          Shopping               37                0
# 1677    2.0          4+  Health & Fitness               38                0
# 2892  1.2.2          4+         Utilities               37                4
# 1880    4.0          4+             Games               37                5
# 3785  1.5.2          4+             Games               40                5
#
#       lang.num  vpp_lic
# 5676         1        1
# 1677         1        1
# 2892         1        1
# 1880         1        1
# 3785         1        1

# %%
data = pd.read_csv('./AppleStore.csv', index_col=0)

data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 1  281656475                                    PAC-MAN Premium   100788224
# 2  281796108                          Evernote - stay organized   158578688
# 3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 5  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 1      USD   3.99             21292                26          4.0
# 2      USD   0.00            161065                26          4.0
# 3      USD   0.00            188583              2822          3.5
# 4      USD   0.00            262241               649          4.0
# 5      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# 1              4.5   6.3.5          4+         Games               38
# 2              3.5   8.2.2          4+  Productivity               37
# 3              4.5   5.0.0          4+       Weather               37
# 4              4.5  5.10.0         12+      Shopping               37
# 5              5.0   7.5.1          4+     Reference               37
#
#    ipadSc_urls.num  lang.num  vpp_lic
# 1                5        10        1
# 2                5        23        1
# 3                5         3        1
# 4                5         9        1
# 5                5        45        1

# %% [markdown]
# Можно узнать размер таблицы, информацию о значениях таблицы, различные статистики по значениям

# %%
data.shape
# Out:
# (7197, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# user_rating_ver     7197 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     7197 non-null int64
# lang.num            7197 non-null int64
# vpp_lic             7197 non-null int64
# dtypes: float64(3), int64(8), object(5)
# memory usage: 955.9+ KB

# %%
data.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# 25%            1.000000     3.500000         2.500000        37.000000
# 50%           23.000000     4.000000         4.000000        37.000000
# 75%          140.000000     4.500000         4.500000        38.000000
# max       177050.000000     5.000000         5.000000        47.000000
#
#        ipadSc_urls.num     lang.num      vpp_lic
# count      7197.000000  7197.000000  7197.000000
# mean          3.707100     5.434903     0.993053
# std           1.986005     7.919593     0.083066
# min           0.000000     0.000000     0.000000
# 25%           3.000000     1.000000     1.000000
# 50%           5.000000     1.000000     1.000000
# 75%           5.000000     8.000000     1.000000
# max           5.000000    75.000000     1.000000

# %% [markdown]
# Чтобы посмотреть, какие колонки есть в таблице, можно воспользоваться `columns`

# %%
data.columns
# Out:
# Index(['id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %% [markdown]
# Метод `values` преобразует `pd.DataFrame` к `np.ndarray`

# %%
data.values
# Out:
# array([[281656475, 'PAC-MAN Premium', 100788224, ..., 5, 10, 1],
#        [281796108, 'Evernote - stay organized', 158578688, ..., 5, 23, 1],
#        [281940292, 'WeatherBug - Local Weather, Radar, Maps, Alerts',
#         100524032, ..., 5, 3, 1],
#        ...,
#        [1187779532, 'Bret Michaels Emojis + Lyric Keyboard', 111322112,
#         ..., 1, 1, 1],
#        [1187838770, 'VR Roller Coaster World - Virtual Reality',
#         97235968, ..., 0, 2, 1],
#        [1188375727, 'Escape the Sweet Shop Series', 90898432, ..., 0, 2,
#         1]], dtype=object)

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
data.values[:,0]
# Out:
# array([281656475, 281796108, 281940292, ..., 1187779532, 1187838770,
#        1188375727], dtype=object)

# %% [markdown]
# Более продвинутое индексирование по таблице: **loc** и **iloc**

# %% [markdown]
# `iloc` - index-based selection

# %%
data.iloc[0]
# Out:
# id                        281656475
# track_name          PAC-MAN Premium
# size_bytes                100788224
# currency                        USD
# price                          3.99
# rating_count_tot              21292
# rating_count_ver                 26
# user_rating                       4
# user_rating_ver                 4.5
# ver                           6.3.5
# cont_rating                      4+
# prime_genre                   Games
# sup_devices.num                  38
# ipadSc_urls.num                   5
# lang.num                         10
# vpp_lic                           1
# Name: 1, dtype: object

# %%
data.iloc[1:3, 1:3]
# Out:
#                                         track_name  size_bytes
# 2                        Evernote - stay organized   158578688
# 3  WeatherBug - Local Weather, Radar, Maps, Alerts   100524032

# %%
data.iloc[[0,1,2], 0]
# Out:
# 1    281656475
# 2    281796108
# 3    281940292
# Name: id, dtype: int64

# %%
data.iloc[-1, :]
# Out:
# id                                    1188375727
# track_name          Escape the Sweet Shop Series
# size_bytes                              90898432
# currency                                     USD
# price                                          0
# rating_count_tot                               3
# rating_count_ver                               3
# user_rating                                    5
# user_rating_ver                                5
# ver                                          1.0
# cont_rating                                   4+
# prime_genre                                Games
# sup_devices.num                               40
# ipadSc_urls.num                                0
# lang.num                                       2
# vpp_lic                                        1
# Name: 11097, dtype: object

# %% [markdown]
# `loc` - label-based selection

# %%
# первое значение - index, второе - имя колонки
data.loc[1, ['id', 'track_name', 'price']]
# Out:
# id                  281656475
# track_name    PAC-MAN Premium
# price                    3.99
# Name: 1, dtype: object

# %% [markdown]
# **Choosing between loc and iloc**
#
# When choosing or transitioning between loc and iloc, there is one "gotcha" worth keeping in mind, which is that the two methods use slightly different indexing schemes.
#
# `iloc` uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.
#
# Why the change? Remember that loc can index any stdlib type: strings, for example. If we have a DataFrame with index values `Apples, ..., Potatoes, ...,` and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index `df.loc['Apples':'Potatoes']` than it is to index something like `df.loc['Apples', 'Potatoet']` (t coming after s in the alphabet).
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case `df.iloc[0:1000]` will return 1000 entries, while `df.loc[0:1000]` return 1001 of them! To get 1000 elements using `loc`, you will need to go one lower and ask for `df.iloc[0:999]`.
#
# Otherwise, the semantics of using `loc` are the same as those for `iloc`.

# %% [markdown]
# `loc` может принимать булевы выражения (так же, как и в случае с `pd.Series`)
#
# Еще один полезный метод - `isin`

# %%
data.loc[data.prime_genre.isin(['Games', 'Shopping'])].head()
# Out:
#            id                                         track_name  size_bytes  \
# 1   281656475                                    PAC-MAN Premium   100788224
# 4   282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 6   283619399                                   Shanghai Mahjong    10485713
# 10  284736660                                        Ms. PAC-MAN    70023168
# 11  284791396                          Solitaire by MobilityWare    49618944
#
#    currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 1       USD   3.99             21292                26          4.0
# 4       USD   0.00            262241               649          4.0
# 6       USD   0.99              8253              5516          4.0
# 10      USD   3.99              7885                40          4.0
# 11      USD   4.99             76720              4017          4.5
#
#     user_rating_ver     ver cont_rating prime_genre  sup_devices.num  \
# 1               4.5   6.3.5          4+       Games               38
# 4               4.5  5.10.0         12+    Shopping               37
# 6               4.0     1.8          4+       Games               47
# 10              4.0   4.0.4          4+       Games               38
# 11              4.5  4.10.1          4+       Games               38
#
#     ipadSc_urls.num  lang.num  vpp_lic
# 1                 5        10        1
# 4                 5         9        1
# 6                 5         1        1
# 10                0        10        1
# 11                4        11        1

# %% [markdown]
# *Задания*

# %% [markdown]
# ---

# %% [markdown]
# ## Получите ответ на следующие вопросы (с помощью pandas):
#
# 1). Сколько приложений с максимальным рейтингом (`user_rating`)?
#
# 2). Сколько всего жанров (`prime_genre`) и какие они? (Hint: `np.unique`)
#
# 3). Сколько суммарно байт (`size_bytes`) весят все приложения жанра Finance?
#
# 4). Сколько всего бесплатных приложений, у которых рейтинг юзеров больше трёх?
#
# 5). Есть ли приложения, которые стоят больше 100 долларов?
#
# 6). Сколько приложений из жанра `Games` или `Shopping`, которые стоят дороже 10 USD или меньше 2 USD, но не являются бесплатными?

# %% [markdown]
# #### 1). Сколько приложений с максимальным рейтингом (user_rating)?

# %%
#mycode
data[data.user_rating == data.user_rating.max()].count().iloc[0]
# Out:
# 492

# %%
#semcode
(data.user_rating == data.user_rating.max()).sum()
# Out:
# 492

# %% [markdown]
# #### 2). Сколько всего жанров (prime_genre) и какие они? (Hint: np.unique)

# %%
#mycode
data.prime_genre.values
# Out:
# array(['Games', 'Productivity', 'Weather', ..., 'Utilities', 'Games',
#        'Games'], dtype=object)

# %%
#semcode
data.prime_genre.unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %%
#semcode
data.prime_genre.value_counts()
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %% [markdown]
# #### 3). Сколько суммарно байт (size_bytes) весят все приложения жанра Finance?

# %%
#semcode
data[data.prime_genre == 'Finance'].size_bytes.sum()
# Out:
# 8136529366

# %% [markdown]
# #### 4). Сколько всего бесплатных приложений, у которых рейтинг юзеров больше трёх?

# %%
#mycode
data[(data.user_rating>3) & (data.price == 0)].iloc[:,0].count()
# Out:
# 2944

# %%
#semcode
len(data[(data.user_rating>3) & (data.price == 0)])
# Out:
# 2944

# %% [markdown]
# #### 5). Есть ли приложения, которые стоят больше 100 долларов?

# %%
#mycode
len(data[data.price > 100]) > 0
# Out:
# True

# %%
#semcode
data[data.price > 100]
# Out:
#              id                      track_name  size_bytes currency   price  \
# 129   308368164  Proloquo2Go - Symbol-based AAC   723764224      USD  249.99
# 1714  551215116             LAMP Words For Life   583263232      USD  299.99
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 129                773                10          4.0              3.5  5.0.1
# 1714                41                 0          4.0              0.0  1.5.5
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 129           4+   Education               37                5         3
# 1714          4+   Education               24                5         1
#
#       vpp_lic
# 129         1
# 1714        1

# %% [markdown]
# #### 6). Сколько приложений из жанра Games или Shopping, которые стоят дороже 10 USD или меньше 2 USD, но не являются бесплатными?

# %%
#mycode
len(data[((data.prime_genre == 'Games') | (data.prime_genre == 'Shopping')) & (data.price > 10) & (0 < data.price) &  (data.price < 2)])
# Out:
# 0

# %%
#semcode
data[(data.price > 10) | ((data.price < 2) & (data.price > 0))]
# Out:
#                id                                  track_name  size_bytes  \
# 6       283619399                            Shanghai Mahjong    10485713
# 22      285946052                                      iQuran    70707916
# 35      289084315                       Period Tracker Deluxe    40216576
# 36      289446241                           Election 2016 Map     2386944
# 39      289894882                                 White Noise    44129280
# 41      290807369                           Line Rider iRide™     1646592
# 54      293760823        iFart - The Original Fart Sounds App    60320768
# 58      294536447                         First Words Animals    32164864
# 59      294631159                                  WeatherPro    69079040
# 63      295759189                   Big Day - Event Countdown    13156352
# 70      297606726                                 Fish Tycoon    13564835
# 74      298206806         iReal Pro - Music Book & Play Along    63283200
# 77      299029654                                         大辞林   210088960
# 81      299949744                                 MotionX GPS    56481792
# 85      300265786             Rowmote: Remote Control for Mac    54088704
# 86      300590611                               Peekaboo Barn    50155520
# 89      301387274                                  Pocket God   145293312
# 92      302049354           Phase 10 Pro - Play Your Friends!    66695168
# 95      303058767                                        MASH    41691136
# 97      303337299                         Wedding Dash Deluxe    55803904
# 102     304871603                                Color Splash    28135424
# 103     304871622                             Zombieville USA    27962441
# 106     305557780                                 iSwap Faces    27069440
# 110     306375551                                  Wind Meter     5234688
# 114     306628397                               Phrase Party!    47774720
# 115     306937053                         Minesweeper Classic    22259712
# 122     307727765                                 Doodle Jump    48741376
# 123     307741537                  LEDit – The LED Banner App    17145856
# 126     308111628                   iCab Mobile (Web Browser)    19451904
# 128     308339980                  iRagdoll - Ragdoll Physics   118683648
# ...           ...                                         ...         ...
# 10691  1172155464                       胜者为王-多人同时在线PK传奇类手机网游！   250616832
# 10693  1172179917         Replica : A Little Temporary Safety   127227904
# 10695  1172449400                   ネイティブ1000人と作った英会話～日常英会話編～    51174400
# 10711  1173333213                             ContactsXL 2017    16477184
# 10718  1173388188                                 修仙幻想-经典萌系回合   187419648
# 10720  1173396715                                 挂机三国-最强挂机游戏   105127936
# 10727  1173451691                               Kendall KMoji    70244352
# 10733  1173642524  Mundo Lanugo en Navidad – Juegos Navideños   225289216
# 10737  1173723621                                        弑仙问情   151494656
# 10750  1173954282                   Mannequin Challenge Maker     4682752
# 10772  1174489793                                  Snowball!!    57315328
# 10774  1174545438            Jurassic VR for Google Cardboard   131453952
# 10785  1174999653                                     WWEmoji   143140864
# 10821  1176374647                                  HealthFace    45356032
# 10848  1176901281                    Web Browser Recorder Pro     1734656
# 10884  1178433845                       新超级群英传OL-单机党必玩的三国群英手游   246023168
# 10894  1178822943                 PetMojis' by The Dog Agency    84905984
# 10910  1179213211       VanDammemoji by Jean-Claude Van Damme    17164288
# 10919  1179475725                       Peppa Pig: Party Time   251977728
# 10928  1179959829                   オービスガイド - 新型オービス&ネズミ捕り&検問    65525760
# 10962  1181016912   Peanuts StoryGIF – Cute GIF & Story Maker    37198848
# 10964  1181025437                        Demi Lovato Stickers    88388608
# 10979  1181526812                               EMOJIZI BOOBA    52536320
# 10980  1181582218       Addon Creator Studio for Minecraft PE    61915136
# 11019  1183709176                          My Diary - 你的名字非官方    18164736
# 11033  1185209084                           Saloons Unleashed   327731200
# 11038  1185428381                                        剑倚手游   178160640
# 11043  1185777521                              问仙奇遇-新玩法新套装嗨到爆   208026624
# 11074  1187128255                  飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）   537462784
# 11087  1187779532       Bret Michaels Emojis + Lyric Keyboard   111322112
#
#       currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 6          USD   0.99              8253              5516          4.0
# 22         USD   1.99              2929               966          4.5
# 35         USD   1.99             13350               489          4.5
# 36         USD   0.99               137                 0          3.0
# 39         USD   0.99             33426               299          4.0
# 41         USD   1.99             21609                69          3.5
# 54         USD   1.99             21825                10          3.0
# 58         USD   1.99              2576                 4          4.0
# 59         USD   1.99              1572                34          4.0
# 63         USD   0.99               812                14          3.0
# 70         USD   0.99             18943              1787          3.5
# 74         USD  12.99              1390               143          4.5
# 77         USD  21.99                64                 0          4.5
# 81         USD   1.99             14970                24          3.5
# 85         USD   0.99              5531                37          3.5
# 86         USD   1.99              3393                77          4.0
# 89         USD   0.99            187529              1071          4.0
# 92         USD   1.99             59155               101          4.5
# 95         USD   1.99              4913                 1          4.0
# 97         USD   0.99             16567              1155          4.5
# 102        USD   0.99             29554                55          4.0
# 103        USD   0.99             32988              2489          4.0
# 106        USD   1.99              2302                 3          3.5
# 110        USD   0.99               338                12          2.5
# 114        USD   1.99               878                48          4.0
# 115        USD   0.99              1140                20          3.5
# 122        USD   0.99            395261                88          4.5
# 123        USD   1.99              2021               147          4.5
# 126        USD   1.99              2441                 4          4.0
# 128        USD   0.99              1372                25          4.0
# ...        ...    ...               ...               ...          ...
# 10691      USD   0.99                 0                 0          0.0
# 10693      USD   1.99                35                19          4.5
# 10695      USD  12.99                 0                 0          0.0
# 10711      USD   1.99                20                 6          4.0
# 10718      USD   0.99                 0                 0          0.0
# 10720      USD   0.99                 0                 0          0.0
# 10727      USD   0.99                11                 0          4.5
# 10733      USD   1.99                 0                 0          0.0
# 10737      USD   0.99                 0                 0          0.0
# 10750      USD   0.99                35                 1          2.0
# 10772      USD   1.99                13                13          5.0
# 10774      USD   1.99                 7                 3          1.5
# 10785      USD   1.99               179                20          4.0
# 10821      USD   1.99                28                 5          3.5
# 10848      USD   1.99                14                 3          2.0
# 10884      USD   0.99                 1                 1          4.0
# 10894      USD   0.99                79                 2          2.0
# 10910      USD   0.99                18                 0          4.5
# 10919      USD   0.99                 9                 0          2.0
# 10928      USD   1.99                 0                 0          0.0
# 10962      USD   0.99                 5                 4          2.5
# 10964      USD   0.99                12                 8          3.5
# 10979      USD   1.99                 1                 1          4.0
# 10980      USD   1.99               214               137          4.0
# 11019      USD   0.99                 0                 0          0.0
# 11033      USD   0.99                 0                 0          0.0
# 11038      USD   0.99                 0                 0          0.0
# 11043      USD   0.99                 0                 0          0.0
# 11074      USD   0.99                 0                 0          0.0
# 11087      USD   1.99                15                 0          4.5
#
#        user_rating_ver      ver cont_rating        prime_genre  \
# 6                  4.0      1.8          4+              Games
# 22                 4.5      3.3          4+          Reference
# 35                 5.0      9.6         12+   Health & Fitness
# 36                 0.0      5.0          4+      Entertainment
# 39                 5.0      7.2          4+   Health & Fitness
# 41                 2.5      2.4          9+      Entertainment
# 54                 4.0    4.0.8          9+      Entertainment
# 58                 5.0      7.0          4+              Games
# 59                 4.5    4.8.2          4+            Weather
# 63                 4.0    8.2.0          4+          Lifestyle
# 70                 4.5    1.1.0          4+              Games
# 74                 5.0    7.0.1          4+              Music
# 77                 0.0    4.1.1          4+          Reference
# 81                 4.5     24.2          4+         Navigation
# 85                 2.5      4.3          4+          Utilities
# 86                 4.0    5.1.0          4+          Education
# 89                 4.0   1.48.2          9+      Entertainment
# 92                 2.5    3.2.0          4+              Games
# 95                 4.0    3.3.2          9+              Games
# 97                 4.5  2.29.13          4+              Games
# 102                5.0    3.6.1          4+      Photo & Video
# 103                4.0      1.7         12+              Games
# 106                5.0      5.1          4+      Photo & Video
# 110                2.0      5.0          4+            Weather
# 114                4.5    8.7.5         17+              Games
# 115                3.5      3.6          4+              Games
# 122                4.5   3.17.6          4+              Games
# 123                4.5    3.5.1          4+          Utilities
# 126                5.0      9.9         17+          Utilities
# 128                4.0    1.8.3         12+              Games
# ...                ...      ...         ...                ...
# 10691              0.0    1.0.1          9+              Games
# 10693              4.5      1.2         12+              Games
# 10695              0.0    1.0.1          4+          Education
# 10711              4.0      1.9          4+       Productivity
# 10718              0.0      1.0          4+              Games
# 10720              0.0   1.3.40         17+              Games
# 10727              0.0      1.1          4+      Entertainment
# 10733              0.0      1.1          4+              Games
# 10737              0.0      1.0          9+              Games
# 10750              5.0      2.3          4+      Photo & Video
# 10772              5.0      1.0          4+              Games
# 10774              1.5      1.2          4+              Games
# 10785              4.0      1.5          9+      Entertainment
# 10821              4.0    1.1.2          4+   Health & Fitness
# 10848              4.5      1.2         17+          Utilities
# 10884              4.0      1.6          9+              Games
# 10894              1.0    1.1.1          4+      Entertainment
# 10910              0.0      1.3         12+      Entertainment
# 10919              0.0    1.1.6          4+          Education
# 10928              0.0    1.1.1          4+         Navigation
# 10962              2.0      1.2          4+      Entertainment
# 10964              3.5      1.1         12+  Social Networking
# 10979              4.0    1.0.1         17+          Utilities
# 10980              4.5      1.2         12+      Entertainment
# 11019              0.0      1.1          4+          Utilities
# 11033              0.0      1.1          4+              Games
# 11038              0.0      1.0          9+              Games
# 11043              0.0      1.0          9+              Games
# 11074              0.0    2.1.0          9+              Games
# 11087              0.0    1.0.2          9+          Utilities
#
#        sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 6                   47                5         1        1
# 22                  43                0         2        1
# 35                  38                0        15        1
# 36                  37                1         1        1
# 39                  37                5         3        1
# 41                  40                0         1        1
# 54                  37                5         1        1
# 58                  38                5         1        1
# 59                  37                0        13        1
# 63                  38                0         7        1
# 70                  47                0         1        1
# 74                  37                5        33        1
# 77                  37                5         2        1
# 81                  37                0         1        1
# 85                  40                3        13        1
# 86                  43                5         1        1
# 89                  43                5         1        1
# 92                  40                5         1        1
# 95                  37                3        15        1
# 97                  43                4         1        1
# 102                 37                0         3        1
# 103                 47                5         1        1
# 106                 37                5         1        1
# 110                 43                0         1        1
# 114                 38                5         1        1
# 115                 37                4         1        1
# 122                 37                0         1        1
# 123                 37                4        12        1
# 126                 38                4        12        1
# 128                 37                2         1        1
# ...                ...              ...       ...      ...
# 10691               38                0         1        1
# 10693               37                5         1        1
# 10695               37                5         1        1
# 10711               37                5         5        1
# 10718               38                5         1        1
# 10720               40                5         1        1
# 10727               37                0         1        1
# 10733               40                5         1        1
# 10737               40                5         1        1
# 10750               37                0         1        1
# 10772               40                4        10        1
# 10774               37                0         1        1
# 10785               37                0         1        1
# 10821               13                0        24        1
# 10848               37                0         3        1
# 10884               37                5         1        1
# 10894               37                0         1        1
# 10910               37                0         1        1
# 10919               40                5         1        1
# 10928               37                5         1        1
# 10962               37                3         9        1
# 10964               37                0         1        1
# 10979               37                0         1        1
# 10980               37                4         1        1
# 11019               37                0         1        1
# 11033               37                5         1        1
# 11038               40                5         0        1
# 11043               38                5         1        1
# 11074               38                5         1        1
# 11087               37                1         1        1
#
# [1446 rows x 16 columns]

# %% [markdown]
# ---

# %% [markdown]
# Мы разобрали только малую часть работы с `pandas`. Это действительно мощный инструмент для работы с данными и его возможности обширны
#
# Из того, что мы не разобрали, стоит обратить внимание на следующие вещи:
#
# * Работа с пропущенными значениями (`fillna`)
# * Объединение таблиц (`join`)
# * Применение к данным функций (`apply`, `applymap`)
# * так же стоит посмотреть, как работать с базами данных в `pandas`

# %% [markdown]
# Список полезных ссылок:
#
# * Официальные туториалы: https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html
#
# * Официальная документация: https://pandas.pydata.org/pandas-docs/stable/
#
# * Статья на Хабре от OpenDataScience сообщества: https://habr.com/company/ods/blog/322626/
#
# * Подробный гайд: https://media.readthedocs.org/pdf/pandasguide/latest/pandasguide.pdf
#
# * Небольшой курс от kaggle: https://www.kaggle.com/learn/pandas

# %% [markdown]
# Главное в работе с новыми библиотеками -- не бояться тыкать в разные функции, смотреть типы возвращаемых объектов и активно пользоваться Яндексом, читать документацию на официальном сайте (она довольно хорошо написана), а ещё лучше понимать всё из docstring'а (`Shift+Tab` при нахождении курсора внутри скобок функции).
